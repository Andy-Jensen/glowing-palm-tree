# %%
import numpy as np
import pandas as pd
from pydataset import data

# %%
pokemon= data('pokemon')
# Out:
# Did you mean:
# pneumon, poisons, pension, coleman, apoeapoc, NOxEmissions

# %%
pokemon = pd.read_csv(r'/Users/andy.jensen/codeup-data-science/pokemon_data.csv')
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#dimensions
pokemon.shape
# Out:
# (800, 12)

# %%
#dtypes
pokemon.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
#column names
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#summary statistics
pokemon.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
#What is the highest HP value present?
pokemon['HP'].max()
# Out:
# 255

# %%
#Create a function named highest_attack.

def highest_attack(x):
    return pokemon['Attack'].max()

# %%
#Use the loaded dataframe as an argument.
highest_attack(pokemon)
# Out:
# 190

# %%
#Which Pokemon possess(es) the highest HP value?
pokemon[pokemon['HP'] == pokemon['HP'].max()]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242  Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 261     55           2      False

# %%
#How many different types are represented in Type 1?
pokemon.groupby('Type 1').nunique()
# Out:
#             #  Name  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        63    69      11  22      41       32       31       31     33
# Dark       28    31       8  20      17       21       22       18     23
# Dragon     24    32       7  19      21       15       18       18     19
# Electric   36    44      10  18      22       24       24       24     25
# Fairy      17    17       1  15      14       15       15       14     16
# Fighting   25    27       4  19      18       16       16       15     21
# Fire       47    52       9  27      36       29       31       26     29
# Flying      3     4       1   3       4        3        4        3      4
# Ghost      23    32       6  20      20       22       21       20     25
# Grass      66    70      10  25      37       30       40       29     38
# Ground     30    32       9  20      25       21       18       16     23
# Ice        23    24       5  13      16       14       17       16     16
# ...

# %%
#Create a function named num_types
def num_types(x):
    return pokemon['Type 1'].nunique()

# %%
#Use the loaded dataframe as an argument
num_types(pokemon)
# Out:
# 18

# %%
#Number of Pokemon whose Type 2 is Ghost
len(pokemon[pokemon['Type 2']=='Ghost'])
# Out:
# 14

# %%
#Percentage of Pokemon whose Type 2 is Ghost
ghost_bois = len(pokemon[(pokemon['Type 1']== 'Ghost') | (pokemon['Type 2']== 'Ghost')])
round((ghost_bois / len(pokemon)) * 100, 2)
# Out:
# 5.75

# %%
pokemon[(pokemon['Type 1']== 'Ghost') | (pokemon['Type 2']== 'Ghost')]
# Out:
#        #                   Name    Type 1  Type 2   HP  Attack  Defense  \
# 99    92                 Gastly     Ghost  Poison   30      35       30
# 100   93                Haunter     Ghost  Poison   45      50       45
# 101   94                 Gengar     Ghost  Poison   60      65       60
# 102   94      GengarMega Gengar     Ghost  Poison   60      65       80
# 215  200             Misdreavus     Ghost     NaN   60      60       60
# 316  292               Shedinja       Bug   Ghost    1      90       45
# 326  302                Sableye      Dark   Ghost   50      75       75
# 327  302    SableyeMega Sableye      Dark   Ghost   50      85      125
# 385  353                Shuppet     Ghost     NaN   44      75       35
# 386  354                Banette     Ghost     NaN   64     115       65
# 387  354    BanetteMega Banette     Ghost     NaN   64     165       75
# 388  355                Duskull     Ghost     NaN   20      40       90
# ...

# %%
#Create a function named percent_ghost
def percent_ghost(df):
    ghost_bois = len(df[(df['Type 1']== 'Ghost') | (df['Type 2']== 'Ghost')])
    return round((ghost_bois / len(df)) * 100, 2)

# %%
#Use the loaded dataframe as an argument
percent_ghost(pokemon)
# Out:
# 5.75

# %%
#Number of Pokemon whose Attack is greater than Defense
len(pokemon[pokemon['Attack'] > pokemon['Defense']])
# Out:
# 433

# %%
#Lowest speed for Grass or Rock
grassrock1 = pokemon[pokemon['Type 1'].isin(['Grass', 'Rock'])]
grassrock2 = pokemon[pokemon['Type 2'].isin(['Grass', 'Rock'])]

grassrock1.min(), grassrock2.min()
pokemon[pokemon['Speed']== 5]
# Out:
# /var/folders/qf/t052sdrx70bffjpl89m9_hz00000gn/T/ipykernel_96250/1416403884.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   grassrock1.min(), grassrock2.min()
#        #      Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213   Shuckle     Bug   Rock   20      10      230       10      230
# 495  446  Munchlax  Normal    NaN  135      85       40       40       85
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 495      5           4      False

# %%
grassrock1 = pokemon[pokemon['Type 1'].isin(['Grass', 'Rock'])]['Speed'].min()
grassrock2 = pokemon[pokemon['Type 2'].isin(['Grass', 'Rock'])]['Speed'].min()
grassrock2
# Out:
# 5

# %%
#Average speed by Generation
pokemon.groupby('Generation').Speed.mean()
# Out:
# Generation
# 1    72.584337
# 2    61.811321
# 3    66.925000
# 4    71.338843
# 5    68.078788
# 6    66.439024
# Name: Speed, dtype: float64
