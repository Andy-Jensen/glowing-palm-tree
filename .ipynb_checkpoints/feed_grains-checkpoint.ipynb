# %%
import pandas as pd
import numpy as np

# %%
df_grain = pd.read_csv(r'/Users/andy.jensen/codeup-data-science/FeedGrains.csv')
df_grain
# Out:
#         SC_Group_ID        SC_Group_Desc  SC_GroupCommod_ID  \
# 0                 1               Prices               17.0
# 1                 1               Prices               17.0
# 2                 1               Prices               17.0
# 3                 1               Prices               17.0
# 4                 1               Prices               17.0
# ...             ...                  ...                ...
# 487383            3  Exports and imports                9.0
# 487384            3  Exports and imports                9.0
# 487385            3  Exports and imports                9.0
# 487386            3  Exports and imports                9.0
# 487387            3  Exports and imports                9.0
#
#        SC_GroupCommod_Desc  SC_Geography_ID  SortOrder  \
# 0                     Oats                1        0.8
# 1                     Oats                1        0.8
# 2                     Oats                1        0.8
# ...

# %%
df_grain.dtypes
# Out:
# SC_Group_ID                    int64
# SC_Group_Desc                 object
# SC_GroupCommod_ID            float64
# SC_GroupCommod_Desc           object
# SC_Geography_ID                int64
# SortOrder                    float64
# SC_GeographyIndented_Desc     object
# SC_Commodity_ID                int64
# SC_Commodity_Desc             object
# SC_Attribute_ID                int64
# SC_Attribute_Desc             object
# SC_Unit_ID                     int64
# SC_Unit_Desc                  object
# Year_ID                        int64
# SC_Frequency_ID                int64
# SC_Frequency_Desc             object
# Timeperiod_ID                  int64
# Timeperiod_Desc               object
# Amount                       float64
# dtype: object

# %%
df_grain.groupby('SC_Group_Desc').SC_GeographyIndented_Desc.unique()
# Out:
# SC_Group_Desc
# Animal unit indexes                                      [United States]
# Exports and imports    [World,   Latin America,       Central America...
# Feed-price ratios                                        [United States]
# Prices                 [United States, U.S. - Central IL, U.S. - Gulf...
# Quantities fed                                           [United States]
# Supply and use         [United States,   World less U.S.,         Mex...
# Transportation                                           [United States]
# Name: SC_GeographyIndented_Desc, dtype: object
